# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
import copy
import pandas as pd
import time
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Loading in data

# %%
print("Loading")
path_Ben_linux_1 = "/home/rubin/Research/data/metadata_IMU_EMG_allgestures_allusers(1).pkl"

start_time = time.time()
data_df = pd.read_pickle(path_Ben_linux_1)
end_time = time.time()
print(f"Completed in {end_time - start_time}s")
# Out:
# Loading
# Completed in 0.04612112045288086s

# %% [markdown]
# # Split Dataset into train and test split, for now just use unimpaired

# %%
pIDs_impaired = ['P102','P103','P104','P105','P106','P107','P108','P109','P110','P111',
       'P112','P114','P115','P116','P118','P119','P121','P122','P123','P124','P125',
       'P126','P127','P128', 'P131', 'P132']
# note participants P001 and P003 because they dont have duplicate or open gestures
pIDs_unimpaired = ['P004','P005','P006','P008','P010','P011']

def split_and_preprocess_by_user(data_df, training_users, test_users):
    metadata_cols = ['Participant', 'Gesture_ID', 'Gesture_Num']

    # Split data by users
    train_df = data_df[data_df['Participant'].isin(training_users)]
    test_df = data_df[data_df['Participant'].isin(test_users)]

    # Subset metadata columns for training and testing sets
    train_metadata_df = train_df[metadata_cols].reset_index(drop=True)
    test_metadata_df = test_df[metadata_cols].reset_index(drop=True)

    # Drop metadata columns from the dataframes
    train_df = train_df.drop(metadata_cols, axis=1).reset_index(drop=True)
    test_df = test_df.drop(metadata_cols, axis=1).reset_index(drop=True)

    # Scale the data
    train_scaler = StandardScaler()

    # Fit on training data and transform both train and test sets
    ppd_train_df = pd.DataFrame(train_scaler.fit_transform(train_df))
    ppd_test_df = pd.DataFrame(train_scaler.transform(test_df))


    # Split IMU and EMG data
    ppd_train_imu_df = ppd_train_df.iloc[:, :72]
    ppd_train_emg_df = ppd_train_df.iloc[:, 72:]
    ppd_test_imu_df = ppd_test_df.iloc[:, :72]
    ppd_test_emg_df = ppd_test_df.iloc[:, 72:]

    # Concatenate metadata back to the processed data
    ppd_train_imu_df = pd.concat([train_metadata_df, ppd_train_imu_df], axis=1)
    ppd_train_emg_df = pd.concat([train_metadata_df, ppd_train_emg_df], axis=1)
    ppd_test_imu_df = pd.concat([test_metadata_df, ppd_test_imu_df], axis=1)
    ppd_test_emg_df = pd.concat([test_metadata_df, ppd_test_emg_df], axis=1)

    return ppd_train_imu_df, ppd_train_emg_df, ppd_test_imu_df, ppd_test_emg_df
    
ppd_train_imu_df, ppd_train_emg_df, ppd_test_imu_df, ppd_test_emg_df = split_and_preprocess_by_user(data_df, ['P006','P008','P010','P011'], ['P004','P005'])

# %%
print(ppd_train_emg_df.shape)
ppd_train_emg_df.head()
# Out:
# (25600, 19)
#   Participant Gesture_ID Gesture_Num        72        73        74        75  \
# 0        P006        pan           6 -0.743813 -0.545412 -0.716175 -1.265814
# 1        P006        pan           6 -0.739128 -0.566745 -0.712895 -1.261461
# 2        P006        pan           6 -0.720411 -0.593631 -0.716057 -1.271174
# 3        P006        pan           6 -0.699357 -0.535351 -0.720962 -1.269762
# 4        P006        pan           6 -0.700718 -0.510521 -0.719368 -1.256697
#
#          76        77        78        79        80        81        82  \
# 0 -0.471762 -0.765925 -0.394592 -0.814324 -0.666034 -0.420698 -0.455580
# 1 -0.495683 -0.638692 -0.286238 -0.812573 -0.666577 -0.409303 -0.452457
# 2 -0.457003 -0.693394 -0.096152 -0.827890 -0.665456 -0.442158 -0.450521
# 3 -0.514277 -0.593569 -0.228329 -0.829022 -0.668456 -0.448856 -0.448315
# 4 -0.573755 -0.743579 -0.303105 -0.826969 -0.669708 -0.450974 -0.446557
#
#          83        84        85        86        87
# 0 -0.523804 -0.401575 -0.589676 -0.013454 -0.459606
# 1 -0.523252 -0.485012 -0.601681 -0.052729 -0.466065
# 2 -0.520637 -0.437734 -0.597538 -0.005312 -0.384134
# 3 -0.525809 -0.438102 -0.600117 -0.122651 -0.359784
# 4 -0.531870 -0.434066 -0.604493 -0.286525 -0.374547

# %%
import numpy as np
import torch
from torch.utils.data import Dataset

class EMG_IMU_Dataset(Dataset):
    def __init__(self, emg_df, imu_df, num_channels_emg=16, num_channels_imu=72, time_units=64):
        # Create labels array using only Gesture_ID from EMG data
        self.labels = emg_df['Gesture_ID'].values
        
        # Exclude metadata columns and reshape the EMG and IMU data
        emg_data = emg_df.drop(['Participant', 'Gesture_ID', 'Gesture_Num'], axis=1).values
        imu_data = imu_df.drop(['Participant', 'Gesture_ID', 'Gesture_Num'], axis=1).values

        # EMG data processing: (num_samples, time_units, num_channels_emg)
        num_samples_emg = len(emg_data) // time_units
        self.emg_data = emg_data.reshape(num_samples_emg, time_units, num_channels_emg).transpose((0, 2, 1))

        # IMU data processing: (num_samples, time_units, num_channels_imu)
        num_samples_imu = len(imu_data) // time_units
        self.imu_data = imu_data.reshape(num_samples_imu, time_units, num_channels_imu).transpose((0, 2, 1))

        # Create a dictionary to map each unique Gesture_ID to an integer label
        unique_labels = np.unique(self.labels)
        self.label_map = {label: i for i, label in enumerate(unique_labels)}
        
        # Map labels to integers
        self.labels = np.array([self.label_map[label] for label in self.labels[:num_samples_emg * time_units:time_units]])

        # Create a dictionary to map (Participant, Gesture_ID, Gesture_Num) to index
        self.index_map = {(row['Participant'], row['Gesture_ID'], row['Gesture_Num']): idx // time_units 
                          for idx, row in emg_df.iterrows()}

        # Sanity check
        print(f"EMG Data shape: {self.emg_data.shape}")
        print(f"IMU Data shape: {self.imu_data.shape}")
        print(f"Labels shape: {self.labels.shape}")
        print(f"Label mapping: {self.label_map}")
    
    def __len__(self):
        return len(self.emg_data)

    def __getitem__(self, idx):
        if isinstance(idx, tuple):
            # Get item by (Participant, Gesture_ID, Gesture_Num)
            idx = self.index_map[idx]
        
        emg_data = torch.tensor(self.emg_data[idx], dtype=torch.float32)
        imu_data = torch.tensor(self.imu_data[idx], dtype=torch.float32)
        label = torch.tensor(self.labels[idx], dtype=torch.long)
        
        return emg_data, imu_data, label

# %%
from torch.utils.data import DataLoader

# Create dataset instances
train_dataset = EMG_IMU_Dataset(ppd_train_emg_df, ppd_train_imu_df)
test_dataset = EMG_IMU_Dataset(ppd_test_emg_df, ppd_test_imu_df)

# Create DataLoader instances
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# EMG Data shape: (400, 16, 64)
# IMU Data shape: (400, 72, 64)
# Labels shape: (400,)
# Label mapping: {'close': 0, 'delete': 1, 'duplicate': 2, 'move': 3, 'open': 4, 'pan': 5, 'rotate': 6, 'select-single': 7, 'zoom-in': 8, 'zoom-out': 9}
# EMG Data shape: (200, 16, 64)
# IMU Data shape: (200, 72, 64)
# Labels shape: (200,)
# Label mapping: {'close': 0, 'delete': 1, 'duplicate': 2, 'move': 3, 'open': 4, 'pan': 5, 'rotate': 6, 'select-single': 7, 'zoom-in': 8, 'zoom-out': 9}

# %%
import torch.nn as nn

class EMG_IMU_CNN(nn.Module):
    def __init__(self, num_classes=10):
        super(EMG_IMU_CNN, self).__init__()
        
        # Convolutional Block for EMG Data (16 channels)
        self.emg_conv1 = nn.Conv1d(in_channels=16, out_channels=32, kernel_size=3, padding=1)
        self.pool = nn.MaxPool1d(kernel_size=2)
        self.emg_conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.emg_conv3 = nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, padding=1)

        # Convolutional Block for IMU Data (72 channels)
        self.imu_conv1 = nn.Conv1d(in_channels=72, out_channels=32, kernel_size=3, padding=1)
        self.imu_conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.imu_conv3 = nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, padding=1)

        # Fully connected layers after concatenation
        # Flattened size of EMG and IMU branches (128 * 8 each)
        self.fc1 = nn.Linear(128 * 8 * 2, 256)  # Multiply by 2 for concatenation of EMG and IMU
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, num_classes)

    def forward(self, emg_input, imu_input):
        # Forward pass for EMG data
        x_emg = torch.relu(self.emg_conv1(emg_input))
        x_emg = self.pool(x_emg)
        x_emg = torch.relu(self.emg_conv2(x_emg))
        x_emg = self.pool(x_emg)
        x_emg = torch.relu(self.emg_conv3(x_emg))
        x_emg = self.pool(x_emg)
        
        # Forward pass for IMU data
        x_imu = torch.relu(self.imu_conv1(imu_input))
        x_imu = self.pool(x_imu)
        x_imu = torch.relu(self.imu_conv2(x_imu))
        x_imu = self.pool(x_imu)
        x_imu = torch.relu(self.imu_conv3(x_imu))
        x_imu = self.pool(x_imu)

        # Flatten both EMG and IMU outputs
        x_emg = torch.flatten(x_emg, start_dim=1)
        x_imu = torch.flatten(x_imu, start_dim=1)

        # Concatenate the EMG and IMU outputs
        x = torch.cat((x_emg, x_imu), dim=1)

        # Pass through the fully connected layers
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        
        return x

# %%
def train(model, optimizer, dataloader, criterion, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for emg_data, imu_data, labels in dataloader:
        # Move EMG data, IMU data, and labels to the device (GPU or CPU)
        emg_data, imu_data, labels = emg_data.to(device), imu_data.to(device), labels.to(device)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass with both EMG and IMU data
        outputs = model(emg_data, imu_data)
        loss = criterion(outputs, labels)
        
        # Backward pass
        loss.backward()

        # Update the weights
        optimizer.step()

        # Update running loss
        running_loss += loss.item()
        
        # Compute accuracy
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

    # Calculate final accuracy for the epoch
    accuracy = 100. * correct / total
    return running_loss / len(dataloader), accuracy

# %%
def evaluate(model, dataloader, criterion, device):
    model.eval()  # Set model to evaluation mode
    running_loss = 0.0
    correct = 0
    total = 0
    
    with torch.no_grad():  # Disable gradient computation
        for emg_data, imu_data, labels in dataloader:
            # Move EMG data, IMU data, and labels to the device (GPU or CPU)
            emg_data, imu_data, labels = emg_data.to(device), imu_data.to(device), labels.to(device)
            
            # Forward pass
            outputs = model(emg_data, imu_data)
            loss = criterion(outputs, labels)
            
            # Update running loss
            running_loss += loss.item()
            
            # Compute accuracy
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    # Compute accuracy over the whole dataset
    accuracy = 100. * correct / total
    return running_loss / len(dataloader), accuracy

# %%
def train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs, device):   
    model.to(device)
    for epoch in range(num_epochs):
        start_time = time.time()

        # Train the model for one epoch
        train_loss, train_acc = train(model, optimizer, train_loader, criterion, device)

        end_time = time.time()
        epoch_time = end_time - start_time

        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%")
        print(f"Epoch Time: {epoch_time:.2f} seconds")
        test_loss, test_acc = evaluate(model, test_loader, criterion, device)
        print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize EMG_IMU_CNN model and move it to the device
emgimu_model = EMG_IMU_CNN().to(device)

# Number of epochs
num_epochs = 100

# Loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(emgimu_model.parameters(), lr=0.0001)

# Train the EMG-IMU model
train_model(emgimu_model, train_loader, test_loader, criterion, optimizer, num_epochs, device)
# Out:
# Epoch 1/100
# Train Loss: 2.3015, Train Acc: 12.00%
# Epoch Time: 0.11 seconds
# Test Loss: 2.3204, Test Acc: 7.00%
# Epoch 2/100
# Train Loss: 2.2937, Train Acc: 14.75%
# Epoch Time: 0.09 seconds
# Test Loss: 2.3244, Test Acc: 10.00%
# Epoch 3/100
# Train Loss: 2.2810, Train Acc: 13.50%
# Epoch Time: 0.09 seconds
# Test Loss: 2.3294, Test Acc: 10.00%
# Epoch 4/100
# Train Loss: 2.2664, Train Acc: 19.25%
# Epoch Time: 0.09 seconds
# Test Loss: 2.3393, Test Acc: 10.50%
# Epoch 5/100
# Train Loss: 2.2490, Train Acc: 22.00%
# Epoch Time: 0.08 seconds
# Test Loss: 2.3673, Test Acc: 9.50%
# Epoch 6/100
# Train Loss: 2.2309, Train Acc: 29.00%
# Epoch Time: 0.08 seconds
# Test Loss: 2.4092, Test Acc: 9.50%
# Epoch 7/100
# Train Loss: 2.2014, Train Acc: 30.75%
# Epoch Time: 0.07 seconds
# Test Loss: 2.5085, Test Acc: 11.50%
# Epoch 8/100
# Train Loss: 2.1597, Train Acc: 35.50%
# Epoch Time: 0.07 seconds
# Test Loss: 2.6194, Test Acc: 11.50%
# Epoch 9/100
# Train Loss: 2.1037, Train Acc: 47.50%
# Epoch Time: 0.07 seconds
# Test Loss: 2.7881, Test Acc: 14.50%
# Epoch 10/100
# Train Loss: 2.0335, Train Acc: 50.75%
# Epoch Time: 0.07 seconds
# Test Loss: 3.0150, Test Acc: 14.00%
# Epoch 11/100
# Train Loss: 1.9492, Train Acc: 51.75%
# Epoch Time: 0.07 seconds
# Test Loss: 3.2197, Test Acc: 15.00%
# Epoch 12/100
# Train Loss: 1.8551, Train Acc: 55.25%
# Epoch Time: 0.07 seconds
# Test Loss: 3.5976, Test Acc: 15.00%
# Epoch 13/100
# Train Loss: 1.7148, Train Acc: 56.75%
# Epoch Time: 0.07 seconds
# Test Loss: 3.9319, Test Acc: 16.00%
# Epoch 14/100
# Train Loss: 1.6120, Train Acc: 61.50%
# Epoch Time: 0.08 seconds
# Test Loss: 4.4781, Test Acc: 17.00%
# Epoch 15/100
# Train Loss: 1.4893, Train Acc: 65.75%
# Epoch Time: 0.07 seconds
# Test Loss: 4.9620, Test Acc: 15.50%
# Epoch 16/100
# Train Loss: 1.3628, Train Acc: 69.75%
# Epoch Time: 0.07 seconds
# Test Loss: 5.7903, Test Acc: 15.50%
# Epoch 17/100
# Train Loss: 1.2029, Train Acc: 72.50%
# Epoch Time: 0.07 seconds
# Test Loss: 6.1293, Test Acc: 16.50%
# Epoch 18/100
# Train Loss: 1.0898, Train Acc: 74.75%
# Epoch Time: 0.07 seconds
# Test Loss: 6.8051, Test Acc: 15.50%
# Epoch 19/100
# Train Loss: 0.9808, Train Acc: 73.25%
# Epoch Time: 0.07 seconds
# Test Loss: 7.3446, Test Acc: 15.50%
# Epoch 20/100
# Train Loss: 0.8958, Train Acc: 81.75%
# Epoch Time: 0.07 seconds
# Test Loss: 7.8291, Test Acc: 16.50%
# Epoch 21/100
# Train Loss: 0.7926, Train Acc: 83.00%
# Epoch Time: 0.08 seconds
# Test Loss: 8.3514, Test Acc: 17.50%
# Epoch 22/100
# Train Loss: 0.7037, Train Acc: 82.25%
# Epoch Time: 0.07 seconds
# Test Loss: 8.6702, Test Acc: 15.00%
# Epoch 23/100
# Train Loss: 0.6223, Train Acc: 86.50%
# Epoch Time: 0.08 seconds
# Test Loss: 9.6077, Test Acc: 15.50%
# Epoch 24/100
# Train Loss: 0.5786, Train Acc: 89.50%
# Epoch Time: 0.07 seconds
# Test Loss: 9.6129, Test Acc: 16.50%
# Epoch 25/100
# Train Loss: 0.5150, Train Acc: 87.75%
# Epoch Time: 0.07 seconds
# Test Loss: 9.8912, Test Acc: 16.00%
# Epoch 26/100
# Train Loss: 0.4828, Train Acc: 93.00%
# Epoch Time: 0.07 seconds
# Test Loss: 10.2121, Test Acc: 16.50%
# Epoch 27/100
# Train Loss: 0.4158, Train Acc: 91.75%
# Epoch Time: 0.07 seconds
# Test Loss: 10.6162, Test Acc: 16.50%
# Epoch 28/100
# Train Loss: 0.4047, Train Acc: 93.00%
# Epoch Time: 0.07 seconds
# Test Loss: 11.0849, Test Acc: 16.50%
# Epoch 29/100
# Train Loss: 0.3655, Train Acc: 94.50%
# Epoch Time: 0.08 seconds
# Test Loss: 11.4729, Test Acc: 15.00%
# Epoch 30/100
# Train Loss: 0.3333, Train Acc: 94.50%
# Epoch Time: 0.08 seconds
# Test Loss: 11.0348, Test Acc: 18.00%
# Epoch 31/100
# Train Loss: 0.3193, Train Acc: 95.50%
# Epoch Time: 0.07 seconds
# Test Loss: 11.5205, Test Acc: 16.50%
# Epoch 32/100
# Train Loss: 0.2624, Train Acc: 96.00%
# Epoch Time: 0.08 seconds
# Test Loss: 11.5010, Test Acc: 17.00%
# Epoch 33/100
# Train Loss: 0.2453, Train Acc: 95.75%
# Epoch Time: 0.08 seconds
# Test Loss: 12.6103, Test Acc: 16.00%
# Epoch 34/100
# Train Loss: 0.2285, Train Acc: 96.25%
# Epoch Time: 0.07 seconds
# Test Loss: 11.9008, Test Acc: 16.00%
# Epoch 35/100
# Train Loss: 0.2016, Train Acc: 97.75%
# Epoch Time: 0.07 seconds
# Test Loss: 12.2413, Test Acc: 17.00%
# Epoch 36/100
# Train Loss: 0.1951, Train Acc: 96.50%
# Epoch Time: 0.08 seconds
# Test Loss: 13.1060, Test Acc: 15.50%
# Epoch 37/100
# Train Loss: 0.1953, Train Acc: 97.00%
# Epoch Time: 0.07 seconds
# Test Loss: 12.7032, Test Acc: 16.00%
# Epoch 38/100
# Train Loss: 0.1678, Train Acc: 97.25%
# Epoch Time: 0.07 seconds
# Test Loss: 13.2183, Test Acc: 15.50%
# Epoch 39/100
# Train Loss: 0.1586, Train Acc: 97.50%
# Epoch Time: 0.07 seconds
# Test Loss: 13.5342, Test Acc: 16.50%
# Epoch 40/100
# Train Loss: 0.1498, Train Acc: 98.00%
# Epoch Time: 0.07 seconds
# Test Loss: 13.6402, Test Acc: 15.50%
# Epoch 41/100
# Train Loss: 0.1428, Train Acc: 98.50%
# Epoch Time: 0.07 seconds
# Test Loss: 13.6405, Test Acc: 16.50%
# Epoch 42/100
# Train Loss: 0.1275, Train Acc: 98.50%
# Epoch Time: 0.07 seconds
# Test Loss: 13.9985, Test Acc: 15.50%
# Epoch 43/100
# Train Loss: 0.1196, Train Acc: 98.50%
# Epoch Time: 0.07 seconds
# Test Loss: 14.5826, Test Acc: 16.00%
# Epoch 44/100
# Train Loss: 0.1126, Train Acc: 98.75%
# Epoch Time: 0.07 seconds
# Test Loss: 14.5109, Test Acc: 16.00%
# Epoch 45/100
# Train Loss: 0.1052, Train Acc: 99.00%
# Epoch Time: 0.07 seconds
# Test Loss: 14.6220, Test Acc: 16.00%
# Epoch 46/100
# Train Loss: 0.1030, Train Acc: 98.00%
# Epoch Time: 0.07 seconds
# Test Loss: 14.8089, Test Acc: 16.00%
# Epoch 47/100
# Train Loss: 0.1083, Train Acc: 99.00%
# Epoch Time: 0.07 seconds
# Test Loss: 14.6458, Test Acc: 16.00%
# Epoch 48/100
# Train Loss: 0.0923, Train Acc: 98.25%
# Epoch Time: 0.07 seconds
# Test Loss: 15.1562, Test Acc: 15.50%
# Epoch 49/100
# Train Loss: 0.0869, Train Acc: 99.75%
# Epoch Time: 0.07 seconds
# Test Loss: 16.3050, Test Acc: 15.50%
# Epoch 50/100
# Train Loss: 0.0790, Train Acc: 99.50%
# Epoch Time: 0.07 seconds
# Test Loss: 15.4505, Test Acc: 16.00%
# Epoch 51/100
# Train Loss: 0.0774, Train Acc: 99.00%
# Epoch Time: 0.07 seconds
# Test Loss: 15.1964, Test Acc: 16.00%
# Epoch 52/100
# Train Loss: 0.0702, Train Acc: 99.75%
# Epoch Time: 0.07 seconds
# Test Loss: 16.2628, Test Acc: 15.00%
# Epoch 53/100
# Train Loss: 0.0669, Train Acc: 99.50%
# Epoch Time: 0.08 seconds
# Test Loss: 16.4597, Test Acc: 15.50%
# Epoch 54/100
# Train Loss: 0.0618, Train Acc: 99.00%
# Epoch Time: 0.08 seconds
# Test Loss: 16.2849, Test Acc: 15.50%
# Epoch 55/100
# Train Loss: 0.0648, Train Acc: 99.75%
# Epoch Time: 0.08 seconds
# Test Loss: 16.1227, Test Acc: 16.00%
# Epoch 56/100
# Train Loss: 0.0526, Train Acc: 99.50%
# Epoch Time: 0.08 seconds
# Test Loss: 16.6175, Test Acc: 15.50%
# Epoch 57/100
# Train Loss: 0.0494, Train Acc: 99.50%
# Epoch Time: 0.07 seconds
# Test Loss: 16.5040, Test Acc: 15.50%
# Epoch 58/100
# Train Loss: 0.0560, Train Acc: 99.75%
# Epoch Time: 0.07 seconds
# Test Loss: 16.5367, Test Acc: 16.00%
# Epoch 59/100
# Train Loss: 0.0475, Train Acc: 99.75%
# Epoch Time: 0.08 seconds
# Test Loss: 16.8157, Test Acc: 16.00%
# Epoch 60/100
# Train Loss: 0.0429, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 17.3455, Test Acc: 15.00%
# Epoch 61/100
# Train Loss: 0.0467, Train Acc: 100.00%
# Epoch Time: 0.08 seconds
# Test Loss: 17.7004, Test Acc: 15.50%
# Epoch 62/100
# Train Loss: 0.0450, Train Acc: 99.75%
# Epoch Time: 0.07 seconds
# Test Loss: 17.4279, Test Acc: 15.50%
# Epoch 63/100
# Train Loss: 0.0400, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 17.2184, Test Acc: 15.00%
# Epoch 64/100
# Train Loss: 0.0412, Train Acc: 99.75%
# Epoch Time: 0.07 seconds
# Test Loss: 17.9680, Test Acc: 15.00%
# Epoch 65/100
# Train Loss: 0.0378, Train Acc: 99.75%
# Epoch Time: 0.07 seconds
# Test Loss: 17.9294, Test Acc: 16.00%
# Epoch 66/100
# Train Loss: 0.0374, Train Acc: 100.00%
# Epoch Time: 0.08 seconds
# Test Loss: 17.7785, Test Acc: 15.00%
# Epoch 67/100
# Train Loss: 0.0383, Train Acc: 100.00%
# Epoch Time: 0.08 seconds
# Test Loss: 18.1187, Test Acc: 15.00%
# Epoch 68/100
# Train Loss: 0.0329, Train Acc: 100.00%
# Epoch Time: 0.09 seconds
# Test Loss: 18.4480, Test Acc: 16.00%
# Epoch 69/100
# Train Loss: 0.0327, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 18.3586, Test Acc: 15.50%
# Epoch 70/100
# Train Loss: 0.0291, Train Acc: 100.00%
# Epoch Time: 0.08 seconds
# Test Loss: 18.2094, Test Acc: 15.50%
# Epoch 71/100
# Train Loss: 0.0260, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 18.3164, Test Acc: 15.50%
# Epoch 72/100
# Train Loss: 0.0273, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 18.6416, Test Acc: 16.00%
# Epoch 73/100
# Train Loss: 0.0241, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 18.5670, Test Acc: 15.00%
# Epoch 74/100
# Train Loss: 0.0265, Train Acc: 100.00%
# Epoch Time: 0.08 seconds
# Test Loss: 19.0017, Test Acc: 15.00%
# Epoch 75/100
# Train Loss: 0.0224, Train Acc: 100.00%
# Epoch Time: 0.08 seconds
# Test Loss: 19.1023, Test Acc: 16.00%
# Epoch 76/100
# Train Loss: 0.0218, Train Acc: 100.00%
# Epoch Time: 0.08 seconds
# Test Loss: 19.2388, Test Acc: 15.50%
# Epoch 77/100
# Train Loss: 0.0207, Train Acc: 100.00%
# Epoch Time: 0.08 seconds
# Test Loss: 19.1543, Test Acc: 15.50%
# Epoch 78/100
# Train Loss: 0.0198, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 19.4519, Test Acc: 15.50%
# Epoch 79/100
# Train Loss: 0.0193, Train Acc: 100.00%
# Epoch Time: 0.08 seconds
# Test Loss: 19.6882, Test Acc: 15.00%
# Epoch 80/100
# Train Loss: 0.0218, Train Acc: 100.00%
# Epoch Time: 0.08 seconds
# Test Loss: 19.6193, Test Acc: 15.00%
# Epoch 81/100
# Train Loss: 0.0176, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 19.6596, Test Acc: 16.00%
# Epoch 82/100
# Train Loss: 0.0173, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 19.7945, Test Acc: 15.50%
# Epoch 83/100
# Train Loss: 0.0174, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 20.0223, Test Acc: 15.50%
# Epoch 84/100
# Train Loss: 0.0156, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 19.8025, Test Acc: 15.00%
# Epoch 85/100
# Train Loss: 0.0169, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 20.0173, Test Acc: 15.50%
# Epoch 86/100
# Train Loss: 0.0143, Train Acc: 100.00%
# Epoch Time: 0.08 seconds
# Test Loss: 20.0544, Test Acc: 15.50%
# Epoch 87/100
# Train Loss: 0.0135, Train Acc: 100.00%
# Epoch Time: 0.08 seconds
# Test Loss: 20.4596, Test Acc: 15.50%
# Epoch 88/100
# Train Loss: 0.0132, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 20.7511, Test Acc: 15.50%
# Epoch 89/100
# Train Loss: 0.0144, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 20.6955, Test Acc: 15.00%
# Epoch 90/100
# Train Loss: 0.0140, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 20.4131, Test Acc: 15.00%
# Epoch 91/100
# Train Loss: 0.0136, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 20.3385, Test Acc: 15.00%
# Epoch 92/100
# Train Loss: 0.0121, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 20.6099, Test Acc: 15.00%
# Epoch 93/100
# Train Loss: 0.0115, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 21.2234, Test Acc: 15.00%
# Epoch 94/100
# Train Loss: 0.0104, Train Acc: 100.00%
# Epoch Time: 0.08 seconds
# Test Loss: 21.5324, Test Acc: 15.50%
# Epoch 95/100
# Train Loss: 0.0109, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 21.4678, Test Acc: 15.50%
# Epoch 96/100
# Train Loss: 0.0107, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 21.4222, Test Acc: 15.00%
# Epoch 97/100
# Train Loss: 0.0097, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 21.2452, Test Acc: 15.50%
# Epoch 98/100
# Train Loss: 0.0098, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 21.2001, Test Acc: 15.50%
# Epoch 99/100
# Train Loss: 0.0092, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 21.4416, Test Acc: 15.50%
# Epoch 100/100
# Train Loss: 0.0098, Train Acc: 100.00%
# Epoch Time: 0.07 seconds
# Test Loss: 21.5825, Test Acc: 15.00%
