# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
import copy
import pandas as pd
import time
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Loading in data

# %%
print("Loading")
path_Ben_linux_1 = "/home/rubin/Research/data/metadata_IMU_EMG_allgestures_allusers(1).pkl"

start_time = time.time()
data_df = pd.read_pickle(path_Ben_linux_1)
end_time = time.time()
print(f"Completed in {end_time - start_time}s")
# Out:
# Loading
# Completed in 0.19711661338806152s

# %%
print("Loading")
path_Ben_linux = "/home/rubin/Research/data/metadata_IMU_EMG_allgestures_allusers.pkl"

start_time = time.time()
data_df1 = pd.read_pickle(path_Ben_linux)
end_time = time.time()
print(f"Completed in {end_time - start_time}s")
# Out:
# Loading
# Completed in 0.9113683700561523s

# %%
print(data_df.head())
# Out:
#   Participant Gesture_ID Gesture_Num   IMU1_ax   IMU1_ay   IMU1_az   IMU1_vx  \
# 0        P102        pan           1  0.341797 -0.939941  0.000977 -0.007450
# 1        P102        pan           1  0.336178 -0.963185  0.003898  0.009595
# 2        P102        pan           1  0.353539 -0.963704  0.011711  0.095966
# 3        P102        pan           1  0.352841 -0.950288  0.011509  0.058836
# 4        P102        pan           1  0.372621 -0.991273  0.029847  0.293946
#
#     IMU1_vy   IMU1_vz   IMU2_ax  ...      EMG7      EMG8      EMG9     EMG10  \
# 0 -0.192625  0.005321 -0.380859  ...  0.000002  0.000002  0.000003  0.000020
# 1 -0.190446 -0.026116 -0.394547  ...  0.000003  0.000003  0.000003  0.000014
# 2 -0.205480 -0.155563 -0.398406  ...  0.000003  0.000003  0.000004  0.000007
# 3 -0.184871 -0.083567 -0.389230  ...  0.000003  0.000003  0.000006  0.000005
# 4 -0.178756 -0.281361 -0.396043  ...  0.000003  0.000002  0.000008  0.000003
#
#       EMG11     EMG12     EMG13     EMG14     EMG15     EMG16
# 0  0.000004  0.000004  0.000002  0.000009  0.000001  0.000002
# 1  0.000007  0.000007  0.000002  0.000017  0.000001  0.000002
# 2  0.000004  0.000005  0.000003  0.000020  0.000003  0.000002
# 3  0.000004  0.000003  0.000004  0.000015  0.000003  0.000003
# 4  0.000007  0.000022  0.000004  0.000017  0.000002  0.000003
#
# [5 rows x 91 columns]

# %% [markdown]
# # Compare Datasets

# %%
print(set(data_df['Gesture_ID'].unique()) ^ set(data_df1['Gesture_ID'].unique()))
# Out:
# {'pinch-and-scroll', 'range-of-motion', 'gesture-3', 'gesture-2', 'gesture-1', 'shake-and-release', 'single-clench', 'gesture-4', 'frequency', 'single-pinch', 'point-and-pinch', 'normal', 'air-tap', 'two-handed-tap', 'double-pinch', 'double-clench', 'palm-pinch', 'gesture-5'}

# %%
print(set(data_df['Gesture_ID'].unique()) - set(data_df1['Gesture_ID'].unique()))
# Out:
# set()

# %%
print(set(data_df1['Gesture_ID'].unique()) - set(data_df['Gesture_ID'].unique()))
# Out:
# {'single-clench', 'gesture-4', 'frequency', 'pinch-and-scroll', 'range-of-motion', 'single-pinch', 'point-and-pinch', 'normal', 'air-tap', 'gesture-3', 'two-handed-tap', 'double-pinch', 'double-clench', 'palm-pinch', 'gesture-5', 'gesture-2', 'gesture-1', 'shake-and-release'}

# %%
print(set(data_df['Participant'].unique()) - set(data_df1['Participant'].unique()))
# Out:
# {'P131'}

# %%
print(set(data_df1['Participant'].unique()) - set(data_df['Participant'].unique()))
# Out:
# set()

# %%
print(data_df1.shape, data_df.shape)
# Out:
# (426752, 91) (204800, 91)

# %%
print(data_df1['Gesture_ID'].unique())
# Out:
# ['pan' 'duplicate' 'gesture-1' 'gesture-2' 'gesture-3' 'gesture-4'
#  'gesture-5' 'normal' 'frequency' 'range-of-motion' 'zoom-out' 'zoom-in'
#  'move' 'rotate' 'select-single' 'delete' 'close' 'open' 'two-handed-tap'
#  'point-and-pinch' 'pinch-and-scroll' 'air-tap' 'palm-pinch'
#  'double-pinch' 'single-pinch' 'single-clench' 'shake-and-release'
#  'double-clench']

# %%
print(data_df1['Participant'].unique())
# Out:
# ['P102' 'P103' 'P104' 'P105' 'P106' 'P107' 'P108' 'P109' 'P110' 'P111'
#  'P112' 'P114' 'P115' 'P116' 'P118' 'P119' 'P121' 'P122' 'P123' 'P124'
#  'P125' 'P126' 'P127' 'P128' 'P132' 'P004' 'P005' 'P006' 'P008' 'P010'
#  'P011']

# %% [markdown]
# ### df has one extra user and less gestures but I'll be using it for now because these are the standard gestures

# %% [markdown]
# # Split Dataset into train and test split, for now just use unimpaired

# %%
metadata_cols = ['Participant', 'Gesture_ID', 'Gesture_Num']
metadata_cols_df = data_df[metadata_cols]
X = data_df.drop(metadata_cols, axis=1)

# %%
pIDs_impaired = ['P102','P103','P104','P105','P106','P107','P108','P109','P110','P111',
       'P112','P114','P115','P116','P118','P119','P121','P122','P123','P124','P125',
       'P126','P127','P128', 'P131', 'P132']
# note participants P001 and P003 because they dont have duplicate or open gestures
pIDs_unimpaired = ['P004','P005','P006','P008','P010','P011']

def split_and_preprocess_by_user(data_df, training_users, test_users):
    metadata_cols = ['Participant', 'Gesture_ID', 'Gesture_Num']

    # Split data by users
    train_df = data_df[data_df['Participant'].isin(training_users)]
    test_df = data_df[data_df['Participant'].isin(test_users)]

    # Subset metadata columns for training and testing sets
    train_metadata_df = train_df[metadata_cols].reset_index(drop=True)
    test_metadata_df = test_df[metadata_cols].reset_index(drop=True)

    # Drop metadata columns from the dataframes
    train_df = train_df.drop(metadata_cols, axis=1).reset_index(drop=True)
    test_df = test_df.drop(metadata_cols, axis=1).reset_index(drop=True)

    # Scale the data
    train_scaler = StandardScaler()
    test_scaler = StandardScaler()

    ppd_train_df = pd.DataFrame(train_scaler.fit_transform(train_df))
    ppd_test_df = pd.DataFrame(test_scaler.fit_transform(test_df))

    # Split IMU and EMG data
    ppd_train_imu_df = ppd_train_df.iloc[:, :72]
    ppd_train_emg_df = ppd_train_df.iloc[:, 72:]
    ppd_test_imu_df = ppd_test_df.iloc[:, :72]
    ppd_test_emg_df = ppd_test_df.iloc[:, 72:]

    # Concatenate metadata back to the processed data
    ppd_train_imu_df = pd.concat([train_metadata_df, ppd_train_imu_df], axis=1)
    ppd_train_emg_df = pd.concat([train_metadata_df, ppd_train_emg_df], axis=1)
    ppd_test_imu_df = pd.concat([test_metadata_df, ppd_test_imu_df], axis=1)
    ppd_test_emg_df = pd.concat([test_metadata_df, ppd_test_emg_df], axis=1)

    return ppd_train_imu_df, ppd_train_emg_df, ppd_test_imu_df, ppd_test_emg_df
    
ppd_train_imu_df, ppd_train_emg_df, ppd_test_imu_df, ppd_test_emg_df = split_and_preprocess_by_user(data_df, ['P006','P008','P010','P011'], ['P004','P005'])

# %%
print(ppd_train_emg_df.shape)
ppd_train_emg_df.head()
# Out:
# (25600, 19)
#   Participant Gesture_ID Gesture_Num        72        73        74        75  \
# 0        P006        pan           6 -0.743813 -0.545412 -0.716175 -1.265814
# 1        P006        pan           6 -0.739128 -0.566745 -0.712895 -1.261461
# 2        P006        pan           6 -0.720411 -0.593631 -0.716057 -1.271174
# 3        P006        pan           6 -0.699357 -0.535351 -0.720962 -1.269762
# 4        P006        pan           6 -0.700718 -0.510521 -0.719368 -1.256697
#
#          76        77        78        79        80        81        82  \
# 0 -0.471762 -0.765925 -0.394592 -0.814324 -0.666034 -0.420698 -0.455580
# 1 -0.495683 -0.638692 -0.286238 -0.812573 -0.666577 -0.409303 -0.452457
# 2 -0.457003 -0.693394 -0.096152 -0.827890 -0.665456 -0.442158 -0.450521
# 3 -0.514277 -0.593569 -0.228329 -0.829022 -0.668456 -0.448856 -0.448315
# 4 -0.573755 -0.743579 -0.303105 -0.826969 -0.669708 -0.450974 -0.446557
#
#          83        84        85        86        87
# 0 -0.523804 -0.401575 -0.589676 -0.013454 -0.459606
# 1 -0.523252 -0.485012 -0.601681 -0.052729 -0.466065
# 2 -0.520637 -0.437734 -0.597538 -0.005312 -0.384134
# 3 -0.525809 -0.438102 -0.600117 -0.122651 -0.359784
# 4 -0.531870 -0.434066 -0.604493 -0.286525 -0.374547

# %%
import numpy as np
import torch
from torch.utils.data import Dataset

class EMGDataset(Dataset):
    def __init__(self, data_df, num_channels=16, time_units=64):
        # Create labels array using only Gesture_ID
        self.labels = data_df['Gesture_ID'].values
        
        # Exclude metadata columns and reshape the data to (num_samples, time_units, num_channels)
        self.data = data_df.drop(['Participant', 'Gesture_ID', 'Gesture_Num'], axis=1).values
        num_samples = len(self.data) // time_units
        self.data = self.data.reshape(num_samples, time_units, num_channels)

        # Transpose data to (num_samples, num_channels, time_units)
        self.data = self.data.transpose((0, 2, 1)) 

        # Create a dictionary to map each unique Gesture_ID to an integer label
        unique_labels = np.unique(self.labels)
        self.label_map = {label: i for i, label in enumerate(unique_labels)}
        # Map labels to integers
        self.labels = np.array([self.label_map[label] for label in self.labels[:num_samples * time_units:time_units]])

        # Create a dictionary to map (Participant, Gesture_ID, Gesture_Num) to index
        self.index_map = {(row['Participant'], row['Gesture_ID'], row['Gesture_Num']): idx // time_units 
                          for idx, row in data_df.iterrows()}

        # Sanity check
        print(f"Data shape: {self.data.shape}")
        print(f"Labels shape: {self.labels.shape}")
        print(f"Label mapping: {self.label_map}")
    
    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        if isinstance(idx, tuple):
            # Get item by (Participant, Gesture_ID, Gesture_Num)
            idx = self.index_map[idx]
        data = torch.tensor(self.data[idx], dtype=torch.float32)
        label = torch.tensor(self.labels[idx], dtype=torch.long)
        return data, label


dataset = EMGDataset(ppd_train_emg_df)

original_data = ppd_train_emg_df[(ppd_train_emg_df['Participant'] == 'P008') &
                                (ppd_train_emg_df['Gesture_ID'] == 'move') &
                                (ppd_train_emg_df['Gesture_Num'] == '6')]

torch_data, torch_label = dataset[('P008', 'move', '6')]

# Get the corresponding data from the original dataset
original_data = original_data.drop(['Participant', 'Gesture_ID', 'Gesture_Num'], axis=1).values
original_data = original_data.transpose()
# Check if the data is the same
print(np.allclose(original_data, torch_data))
print(torch_data.shape)
print(torch_label)
# Out:
# Data shape: (400, 16, 64)
# Labels shape: (400,)
# Label mapping: {'close': 0, 'delete': 1, 'duplicate': 2, 'move': 3, 'open': 4, 'pan': 5, 'rotate': 6, 'select-single': 7, 'zoom-in': 8, 'zoom-out': 9}
# True
# torch.Size([16, 64])
# tensor(3)

# %%
from torch.utils.data import DataLoader

# Create dataset instances
train_dataset = EMGDataset(ppd_train_emg_df)
test_dataset = EMGDataset(ppd_test_emg_df)

# Create DataLoader instances
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Data shape: (400, 16, 64)
# Labels shape: (400,)
# Label mapping: {'close': 0, 'delete': 1, 'duplicate': 2, 'move': 3, 'open': 4, 'pan': 5, 'rotate': 6, 'select-single': 7, 'zoom-in': 8, 'zoom-out': 9}
# Data shape: (200, 16, 64)
# Labels shape: (200,)
# Label mapping: {'close': 0, 'delete': 1, 'duplicate': 2, 'move': 3, 'open': 4, 'pan': 5, 'rotate': 6, 'select-single': 7, 'zoom-in': 8, 'zoom-out': 9}

# %%
import torch.nn as nn

class EMGCNN(nn.Module):
    def __init__(self, num_classes=10):
        super(EMGCNN, self).__init__()
        
        # Convolutional Block 1
        self.conv1 = nn.Conv1d(in_channels=16, out_channels=32, kernel_size=3, padding=1)
        self.pool = nn.MaxPool1d(kernel_size=2)
        
        # Convolutional Block 2
        self.conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        
        # Convolutional Block 3
        self.conv3 = nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, padding=1)
        
        # After applying three convolutional blocks and pooling, 
        # the input size reduces; calculate the flattened size
        # Assuming input size is (16, 64):
        # After pool1 -> (32, 32)
        # After pool2 -> (64, 16)
        # After pool3 -> (128, 8)

        self.fc1 = nn.Linear(1024, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, num_classes)


    def forward(self, x):
        print(x.shape)
        x = torch.relu(self.conv1(x))
        x = self.pool(x)
        x = torch.relu(self.conv2(x))
        x = self.pool(x)
        x = torch.relu(self.conv3(x))
        x = self.pool(x)
        
        # Flatten the tensor for the fully connected layers
        x = torch.flatten(x, start_dim=1) 
        
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
emg_model = EMGCNN()
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(emg_model.parameters(), lr=0.001)

# %%
def train(model, optimizer, dataloader, criterion, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for data, labels in dataloader:
        data, labels = data.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(data)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

    accuracy = 100. * correct / total
    return running_loss / len(dataloader), accuracy

# %%
def evaluate(model, dataloader, criterion, device):
    model.eval()
    running_loss = 0.0
    correct = 0
    total = 0
    
    with torch.no_grad():
        for data, labels in dataloader:
            data, labels = data.to(device), labels.to(device)
            outputs = model(data)
            loss = criterion(outputs, labels)

            running_loss += loss.item()
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    accuracy = 100. * correct / total
    return running_loss / len(dataloader), accuracy

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
emg_model = EMGCNN().to(device)

num_epochs = 100

def train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs, device):
    model.to(device)
    for epoch in range(num_epochs):
        start_time = time.time()
        train_loss, train_acc = train(model, optimizer, train_loader, criterion, device)
        end_time = time.time()
        epoch_time = end_time - start_time
        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%")
        print(f"Epoch Time: {epoch_time:.2f} seconds")

train_model(emg_model, train_loader, test_loader, criterion, optimizer, num_epochs, device)
# Out:
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 1/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.05 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 2/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.04 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 3/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.04 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 4/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.04 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 5/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.04 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 6/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.05 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 7/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.04 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 8/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 9/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 10/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 11/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 12/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 13/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 14/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 15/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 16/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 17/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 18/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 19/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 20/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 21/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 22/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 23/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 24/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 25/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 26/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 27/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 28/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 29/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 30/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 31/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 32/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 33/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 34/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 35/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 36/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 37/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 38/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 39/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 40/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 41/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 42/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 43/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 44/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 45/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 46/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 47/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 48/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 49/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 50/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 51/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 52/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 53/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 54/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 55/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 56/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 57/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 58/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 59/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 60/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 61/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 62/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 63/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 64/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 65/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 66/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 67/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 68/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 69/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 70/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 71/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 72/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 73/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 74/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 75/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 76/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 77/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 78/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 79/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 80/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 81/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 82/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 83/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 84/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 85/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 86/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 87/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 88/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 89/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 90/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 91/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 92/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 93/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 94/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 95/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 96/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 97/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 98/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 99/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([64, 16, 64])
# torch.Size([16, 16, 64])
# Epoch 100/100
# Train Loss: 2.3032, Train Acc: 10.00%
# Epoch Time: 0.03 seconds

# %%
for name, param in emg_model.named_parameters():
    if param.requires_grad:
        print(name, param.grad)
# Out:
# conv1.weight tensor([[[-0.1045, -0.0496, -0.0301],
#          [ 0.2906,  0.3807,  0.4038],
#          [ 0.6103,  0.5264,  0.4534],
#          ...,
#          [ 0.1474,  0.1835,  0.0886],
#          [ 0.0834,  0.1354,  0.1554],
#          [ 0.0033, -0.0969, -0.1013]],
#
#         [[-0.0437, -0.0399, -0.0282],
#          [ 0.1008,  0.0600,  0.0453],
#          [ 0.2468,  0.1993,  0.1999],
#          ...,
#          [ 0.0574,  0.0539,  0.0986],
#          [ 0.0737,  0.0594,  0.0487],
#          [-0.0469, -0.0020,  0.0361]],
#
#         [[-0.0437, -0.0423, -0.0076],
#          [ 0.1034,  0.1017,  0.1171],
#          [ 0.2559,  0.2737,  0.2687],
#          ...,
#          [ 0.0817,  0.0624, -0.0216],
#          [-0.0847, -0.0731, -0.0738],
#          [ 0.0962,  0.1215,  0.0901]],
#
#         ...,
#
#         [[-0.0353,  0.0191,  0.0250],
#          [-0.1844, -0.2166, -0.2266],
#          [-0.5891, -0.5801, -0.4573],
#          ...,
#          [ 0.0648,  0.0500,  0.0414],
#          [-0.0918, -0.0503, -0.1103],
#          [ 0.0814,  0.0901,  0.0870]],
#
#         [[ 0.0083,  0.0665,  0.1232],
#          [-0.0051,  0.0175,  0.0087],
#          [ 0.0557,  0.0590,  0.0886],
#          ...,
#          [ 0.0088,  0.0182,  0.0287],
#          [-0.2749, -0.2546, -0.1805],
#          [-0.0224, -0.0263, -0.0551]],
#
#         [[ 0.3026,  0.2650,  0.1920],
#          [ 0.0522,  0.0419,  0.0345],
#          [ 0.0472,  0.0124,  0.0230],
#          ...,
#          [-0.2908, -0.2638, -0.2611],
#          [-0.0972, -0.0872, -0.0612],
#          [-0.0538,  0.0482,  0.0437]]])
# conv1.bias tensor([ 0.0554,  0.0296, -0.1189,  0.0751, -0.1602,  0.0248,  0.2259,  0.1055,
#         -0.0763,  0.0909, -0.1306, -0.1477, -0.0887,  0.1340,  0.0664, -0.1181,
#          0.0826, -0.0973, -0.0040, -0.1465, -0.0899,  0.3103, -0.0031, -0.0072,
#         -0.1071, -0.1708,  0.0837,  0.1131,  0.1721, -0.0409, -0.0273,  0.0655])
# conv2.weight tensor([[[-0.0154, -0.0401, -0.0709],
#          [ 0.0373,  0.0434,  0.0511],
#          [ 0.0656,  0.0061, -0.0199],
#          ...,
#          [ 0.1198,  0.0681,  0.0506],
#          [-0.0168, -0.0051, -0.0274],
#          [ 0.1143,  0.0830,  0.0791]],
#
#         [[ 0.0663,  0.0713,  0.0765],
#          [ 0.1771,  0.1483,  0.1112],
#          [ 0.1308,  0.0956,  0.1178],
#          ...,
#          [-0.2066, -0.1311, -0.1057],
#          [-0.0115, -0.0025, -0.0159],
#          [-0.0162,  0.0284,  0.0760]],
#
#         [[-0.0474, -0.0122,  0.0139],
#          [-0.1767, -0.1151, -0.0965],
#          [ 0.0797,  0.0565,  0.0636],
#          ...,
#          [ 0.0259,  0.0422,  0.0535],
#          [-0.0086, -0.0560, -0.0403],
#          [-0.0477, -0.0842, -0.1358]],
#
#         ...,
#
#         [[ 0.0591,  0.0293,  0.0060],
#          [-0.0409, -0.0309,  0.0004],
#          [-0.1796, -0.1517, -0.1081],
#          ...,
#          [-0.1742, -0.1663, -0.1809],
#          [ 0.0959,  0.1185,  0.0953],
#          [-0.1470, -0.1415, -0.0681]],
#
#         [[-0.2137, -0.1495, -0.1900],
#          [-0.1439, -0.1686, -0.1772],
#          [-0.0354, -0.0596, -0.0573],
#          ...,
#          [-0.4044, -0.3563, -0.3933],
#          [ 0.0171,  0.0063,  0.0081],
#          [ 0.0148, -0.0747, -0.0320]],
#
#         [[ 0.0154, -0.0363, -0.0586],
#          [ 0.0789,  0.0649,  0.1492],
#          [-0.0955, -0.0903, -0.0588],
#          ...,
#          [ 0.0808,  0.0520, -0.0326],
#          [ 0.0008,  0.0047, -0.0354],
#          [-0.0749, -0.0254,  0.0155]]])
# conv2.bias tensor([-0.1277,  0.1244, -0.0887, -0.1552, -0.1705,  0.3437,  0.3968,  0.1119,
#         -0.1475,  0.0034, -0.4001,  0.2328,  0.1412,  0.0409, -0.6058,  0.0305,
#         -0.4059,  0.0557, -0.0688, -0.0812, -0.3866,  0.2806, -0.0298,  0.0268,
#          0.2908, -0.0691, -0.2030, -0.1440,  0.0747,  0.1202, -0.3538, -0.0144,
#          0.0541, -0.1136,  0.3105, -0.0140,  0.3189, -0.0946, -0.2613, -0.0367,
#          0.2239,  0.0640, -0.0545, -0.0206, -0.0865,  0.0442, -0.2518, -0.0161,
#          0.3916, -0.1581,  0.0610,  0.1795, -0.2929,  0.0147,  0.6543,  0.0836,
#          0.0488, -0.1567,  0.0203, -0.0572,  0.5443, -0.0450, -0.4877, -0.0793])
# conv3.weight tensor([[[ 0.0011,  0.0239, -0.0059],
#          [ 0.0520,  0.0480,  0.0409],
#          [ 0.0708,  0.0487, -0.0099],
#          ...,
#          [ 0.0526,  0.0336,  0.0031],
#          [ 0.0807,  0.1137,  0.1325],
#          [ 0.0556,  0.0449, -0.0325]],
#
#         [[-0.0010, -0.0089, -0.0132],
#          [-0.0055, -0.0796, -0.0874],
#          [-0.1305, -0.1576, -0.1564],
#          ...,
#          [-0.0240, -0.0410, -0.0569],
#          [-0.0548, -0.0596, -0.0779],
#          [-0.0386, -0.1019, -0.1010]],
#
#         [[-0.0154,  0.0054,  0.0100],
#          [ 0.0128,  0.0583,  0.0241],
#          [ 0.0040,  0.0119,  0.0061],
#          ...,
#          [-0.0173, -0.0063, -0.0030],
#          [ 0.2395,  0.1929,  0.2190],
#          [-0.0272,  0.0117, -0.0004]],
#
#         ...,
#
#         [[-0.0451, -0.0155, -0.0112],
#          [-0.1112, -0.0297,  0.0625],
#          [ 0.0754,  0.0589,  0.1144],
#          ...,
#          [-0.0541, -0.0437, -0.0015],
#          [ 0.0780,  0.0778,  0.1551],
#          [ 0.1054,  0.0697,  0.0606]],
#
#         [[-0.0234,  0.0332,  0.0446],
#          [-0.1497,  0.0604,  0.0296],
#          [-0.1510, -0.0540, -0.0784],
#          ...,
#          [ 0.1407,  0.1446,  0.1075],
#          [-0.1752, -0.1366, -0.1037],
#          [-0.0532,  0.0401,  0.0470]],
#
#         [[ 0.0130,  0.0244,  0.0538],
#          [ 0.0118,  0.0210,  0.0408],
#          [-0.0417,  0.0036,  0.0631],
#          ...,
#          [ 0.0003,  0.0419,  0.0190],
#          [ 0.0012,  0.0564, -0.0158],
#          [-0.0407, -0.0188,  0.0402]]])
# conv3.bias tensor([ 0.2357, -0.1281,  0.2340, -0.0563, -0.2572,  0.5687,  0.3847,  0.3503,
#         -0.1117, -0.2098,  0.2259,  0.0657,  0.0012, -0.2889, -0.0092, -0.3546,
#          0.2487,  0.0974,  0.5417,  0.4283, -0.4886, -0.2605, -0.0659,  0.2985,
#         -0.0304, -0.3879,  0.2786,  0.0123, -0.0469,  0.2686, -0.3874, -0.0032,
#         -0.0979, -0.1243,  0.2392, -0.5949, -0.0437,  0.1824, -0.0773,  0.8128,
#          0.1805,  0.0106, -0.5022,  0.0282,  0.0818, -0.4724, -0.0025,  0.0380,
#          0.7555,  0.0801,  0.8392,  0.0410,  0.1536,  0.3901, -0.0210,  0.3294,
#          0.3463, -0.3850,  0.0388, -0.0031,  0.0988,  0.2279, -0.2835,  0.1919,
#          0.0850,  0.1910, -1.0238,  0.5600,  0.1846,  0.4321, -0.2735,  0.1228,
#          0.3176, -0.0280, -0.0586,  0.3151,  0.8064,  0.0146, -0.4203, -0.0197,
#          0.0099, -0.3545, -0.6331,  0.7314,  0.2713,  0.1369,  0.9125, -0.6726,
#         -0.4139,  0.1553, -0.2092, -0.3329, -0.7252, -0.1714,  0.9674,  0.3453,
#          0.3366,  0.1822, -0.0971, -0.5972,  0.2280, -0.5751,  0.5732,  0.2790,
#          0.1708,  0.5002,  0.1485, -1.0465, -0.0025,  0.1134, -0.1674,  0.0073,
#         -0.0322,  0.0481, -0.0085,  0.7979, -0.2937,  0.0622, -0.1644, -0.1159,
