# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
import os
import copy
import pandas as pd
import time
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Loading in data

# %%
print("Loading")
path_Ben_linux_1 = "/home/rubin/Research/data/metadata_IMU_EMG_allgestures_allusers(1).pkl"

start_time = time.time()
data_df = pd.read_pickle(path_Ben_linux_1)
end_time = time.time()
print(f"Completed in {end_time - start_time}s")
# Out:
# Loading
# Completed in 0.08310842514038086s

# %% [markdown]
# # Split Dataset into train and test split

# %%
# Impaired participants
pIDs_impaired = ['P102', 'P103', 'P104', 'P105', 'P106', 'P107', 'P108', 'P109', 'P110', 'P111',
                 'P112', 'P114', 'P115', 'P116', 'P118', 'P119', 'P121', 'P122', 'P123', 'P124', 
                 'P125', 'P126', 'P127', 'P128', 'P131', 'P132']

# Unimpaired participants
pIDs_unimpaired = ['P004', 'P005', 'P006', 'P008', 'P010', 'P011']

def split_and_preprocess_by_user(data_df, pIDs_impaired, pIDs_unimpaired, test_size=0.2):
    # Split impaired and unimpaired participants into train and test sets
    impaired_train, impaired_test = train_test_split(pIDs_impaired, test_size=test_size, random_state=42)
    unimpaired_train, unimpaired_test = train_test_split(pIDs_unimpaired, test_size=test_size, random_state=42)

    # Combine train and test users
    training_users = impaired_train + unimpaired_train
    test_users = impaired_test + unimpaired_test

    metadata_cols = ['Participant', 'Gesture_ID', 'Gesture_Num']

    # Split data by users
    train_df = data_df[data_df['Participant'].isin(training_users)]
    test_df = data_df[data_df['Participant'].isin(test_users)]

    # Subset metadata columns for training and testing sets
    train_metadata_df = train_df[metadata_cols].reset_index(drop=True)
    test_metadata_df = test_df[metadata_cols].reset_index(drop=True)

    # Drop metadata columns from the dataframes
    train_df = train_df.drop(metadata_cols, axis=1).reset_index(drop=True)
    test_df = test_df.drop(metadata_cols, axis=1).reset_index(drop=True)

    # Scale the data
    train_scaler = StandardScaler()

    # Fit on training data and transform both train and test sets
    ppd_train_df = pd.DataFrame(train_scaler.fit_transform(train_df))
    ppd_test_df = pd.DataFrame(train_scaler.transform(test_df))

    # Split IMU and EMG data
    ppd_train_imu_df = ppd_train_df.iloc[:, :72]
    ppd_train_emg_df = ppd_train_df.iloc[:, 72:]
    ppd_test_imu_df = ppd_test_df.iloc[:, :72]
    ppd_test_emg_df = ppd_test_df.iloc[:, 72:]

    # Concatenate metadata back to the processed data
    ppd_train_imu_df = pd.concat([train_metadata_df, ppd_train_imu_df], axis=1)
    ppd_train_emg_df = pd.concat([train_metadata_df, ppd_train_emg_df], axis=1)
    ppd_test_imu_df = pd.concat([test_metadata_df, ppd_test_imu_df], axis=1)
    ppd_test_emg_df = pd.concat([test_metadata_df, ppd_test_emg_df], axis=1)

    return ppd_train_imu_df, ppd_train_emg_df, ppd_test_imu_df, ppd_test_emg_df

# Call the function with the full participant list
ppd_train_imu_df, ppd_train_emg_df, ppd_test_imu_df, ppd_test_emg_df = split_and_preprocess_by_user(data_df, pIDs_impaired, pIDs_unimpaired)

# %%
print(ppd_train_imu_df.shape)
ppd_train_emg_df.head()
# Out:
# (153600, 75)
#   Participant Gesture_ID Gesture_Num        72        73        74        75  \
# 0        P103       move           1 -0.272553 -0.174909 -0.487032 -0.479092
# 1        P103       move           1 -0.237541 -0.219476 -0.491541 -0.456715
# 2        P103       move           1 -0.226202 -0.227727 -0.498172 -0.514807
# 3        P103       move           1 -0.059969 -0.167775 -0.476214 -0.597320
# 4        P103       move           1 -0.012488 -0.202698 -0.483415 -0.510942
#
#          76        77        78        79        80        81        82  \
# 0 -0.282206 -0.340962 -0.349967 -0.372957 -0.460476 -0.322696 -0.353601
# 1 -0.259345 -0.269619 -0.370232 -0.354646 -0.456982 -0.301867 -0.349724
# 2 -0.247238 -0.248624 -0.340924 -0.330598 -0.453981 -0.294390 -0.355787
# 3 -0.266217 -0.281169 -0.308048 -0.280282 -0.518521 -0.294813 -0.355749
# 4 -0.278117 -0.243418 -0.328787 -0.316063 -0.439284 -0.295585 -0.346027
#
#          83        84        85        86        87
# 0 -0.359954 -0.341444 -0.270736 -0.129773 -0.256569
# 1 -0.356034 -0.337765 -0.281176 -0.106944 -0.250600
# 2 -0.360192 -0.341552 -0.274673 -0.068181 -0.182230
# 3 -0.350663 -0.333018 -0.264322 -0.065513 -0.144634
# 4 -0.350198 -0.327595 -0.256635 -0.112046 -0.256429

# %%
import numpy as np
import torch
from torch.utils.data import Dataset

class EMG_IMU_Dataset(Dataset):
    def __init__(self, emg_df, imu_df, num_channels_emg=16, num_channels_imu=72, time_units=64):
        # Create labels array using only Gesture_ID from EMG data
        self.labels = emg_df['Gesture_ID'].values
        
        # Exclude metadata columns and reshape the EMG and IMU data
        emg_data = emg_df.drop(['Participant', 'Gesture_ID', 'Gesture_Num'], axis=1).values
        imu_data = imu_df.drop(['Participant', 'Gesture_ID', 'Gesture_Num'], axis=1).values

        # EMG data processing: (num_samples, time_units, num_channels_emg)
        num_samples_emg = len(emg_data) // time_units
        self.emg_data = emg_data.reshape(num_samples_emg, time_units, num_channels_emg).transpose((0, 2, 1))

        # IMU data processing: (num_samples, time_units, num_channels_imu)
        num_samples_imu = len(imu_data) // time_units
        self.imu_data = imu_data.reshape(num_samples_imu, time_units, num_channels_imu).transpose((0, 2, 1))

        # Create a dictionary to map each unique Gesture_ID to an integer label
        unique_labels = np.unique(self.labels)
        self.label_map = {label: i for i, label in enumerate(unique_labels)}
        
        # Map labels to integers
        self.labels = np.array([self.label_map[label] for label in self.labels[:num_samples_emg * time_units:time_units]])

        # Create a dictionary to map (Participant, Gesture_ID, Gesture_Num) to index
        self.index_map = {(row['Participant'], row['Gesture_ID'], row['Gesture_Num']): idx // time_units 
                          for idx, row in emg_df.iterrows()}

        # Sanity check
        print(f"EMG Data shape: {self.emg_data.shape}")
        print(f"IMU Data shape: {self.imu_data.shape}")
        print(f"Labels shape: {self.labels.shape}")
        print(f"Label mapping: {self.label_map}")
    
    def __len__(self):
        return len(self.emg_data)

    def __getitem__(self, idx):
        if isinstance(idx, tuple):
            # Get item by (Participant, Gesture_ID, Gesture_Num)
            idx = self.index_map[idx]
        
        emg_data = torch.tensor(self.emg_data[idx], dtype=torch.float32)
        imu_data = torch.tensor(self.imu_data[idx], dtype=torch.float32)
        label = torch.tensor(self.labels[idx], dtype=torch.long)
        
        return emg_data, imu_data, label

# %%
from torch.utils.data import DataLoader

# Create dataset instances
train_dataset = EMG_IMU_Dataset(ppd_train_emg_df, ppd_train_imu_df)
test_dataset = EMG_IMU_Dataset(ppd_test_emg_df, ppd_test_imu_df)

# Create DataLoader instances
batch_size = 64
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# EMG Data shape: (2400, 16, 64)
# IMU Data shape: (2400, 72, 64)
# Labels shape: (2400,)
# Label mapping: {'close': 0, 'delete': 1, 'duplicate': 2, 'move': 3, 'open': 4, 'pan': 5, 'rotate': 6, 'select-single': 7, 'zoom-in': 8, 'zoom-out': 9}
# EMG Data shape: (800, 16, 64)
# IMU Data shape: (800, 72, 64)
# Labels shape: (800,)
# Label mapping: {'close': 0, 'delete': 1, 'duplicate': 2, 'move': 3, 'open': 4, 'pan': 5, 'rotate': 6, 'select-single': 7, 'zoom-in': 8, 'zoom-out': 9}

# %%
import torch.nn as nn

class EMG_IMU_CNN(nn.Module):
    def __init__(self, num_classes=10, dropout_prob=0.5):
        super(EMG_IMU_CNN, self).__init__()

        # Convolutional Block for EMG Data (16 channels)
        self.emg_conv1 = nn.Conv1d(in_channels=16, out_channels=32, kernel_size=3, padding=1)
        self.emg_bn1 = nn.BatchNorm1d(32)
        self.emg_conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.emg_bn2 = nn.BatchNorm1d(64)
        self.emg_conv3 = nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, padding=1)
        self.emg_bn3 = nn.BatchNorm1d(128)
        
        # Convolutional Block for IMU Data (72 channels)
        self.imu_conv1 = nn.Conv1d(in_channels=72, out_channels=32, kernel_size=3, padding=1)
        self.imu_bn1 = nn.BatchNorm1d(32)
        self.imu_conv2 = nn.Conv1d(in_channels=32, out_channels=64, kernel_size=3, padding=1)
        self.imu_bn2 = nn.BatchNorm1d(64)
        self.imu_conv3 = nn.Conv1d(in_channels=64, out_channels=128, kernel_size=3, padding=1)
        self.imu_bn3 = nn.BatchNorm1d(128)
        
        # Pooling layer (shared)
        self.pool = nn.MaxPool1d(kernel_size=2)

        # Dropout
        self.dropout = nn.Dropout(p=dropout_prob)

        # Fully connected layers after concatenation
        self.fc1 = nn.Linear(128 * 8 * 2, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, num_classes)

    def forward(self, emg_input, imu_input):
        # Forward pass for EMG data
        x_emg = torch.relu(self.emg_bn1(self.emg_conv1(emg_input)))
        x_emg = self.pool(x_emg)
        x_emg = torch.relu(self.emg_bn2(self.emg_conv2(x_emg)))
        x_emg = self.pool(x_emg)
        x_emg = torch.relu(self.emg_bn3(self.emg_conv3(x_emg)))
        x_emg = self.pool(x_emg)
        x_emg = self.dropout(x_emg)  # Dropout after final EMG conv block
        
        # Forward pass for IMU data
        x_imu = torch.relu(self.imu_bn1(self.imu_conv1(imu_input)))
        x_imu = self.pool(x_imu)
        x_imu = torch.relu(self.imu_bn2(self.imu_conv2(x_imu)))
        x_imu = self.pool(x_imu)
        x_imu = torch.relu(self.imu_bn3(self.imu_conv3(x_imu)))
        x_imu = self.pool(x_imu)
        x_imu = self.dropout(x_imu)  # Dropout after final IMU conv block

        # Flatten both EMG and IMU outputs
        x_emg = torch.flatten(x_emg, start_dim=1)
        x_imu = torch.flatten(x_imu, start_dim=1)

        # Concatenate the EMG and IMU outputs
        x = torch.cat((x_emg, x_imu), dim=1)

        # Pass through the fully connected layers with dropout
        x = self.dropout(torch.relu(self.fc1(x)))
        x = self.dropout(torch.relu(self.fc2(x)))
        x = self.fc3(x)
        
        return x

# %%
def train(model, optimizer, dataloader, criterion, device):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0
    
    for emg_data, imu_data, labels in dataloader:
        # Move EMG data, IMU data, and labels to the device (GPU or CPU)
        emg_data, imu_data, labels = emg_data.to(device), imu_data.to(device), labels.to(device)

        # Zero the gradients
        optimizer.zero_grad()

        # Forward pass with both EMG and IMU data
        outputs = model(emg_data, imu_data)
        loss = criterion(outputs, labels)
        
        # Backward pass
        loss.backward()

        # Update the weights
        optimizer.step()

        # Update running loss
        running_loss += loss.item()
        
        # Compute accuracy
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

    # Calculate final accuracy for the epoch
    accuracy = 100. * correct / total
    return running_loss / len(dataloader), accuracy

# %%
def evaluate(model, dataloader, criterion, device):
    model.eval()  # Set model to evaluation mode
    running_loss = 0.0
    correct = 0
    total = 0
    
    with torch.no_grad():  # Disable gradient computation
        for emg_data, imu_data, labels in dataloader:
            # Move EMG data, IMU data, and labels to the device (GPU or CPU)
            emg_data, imu_data, labels = emg_data.to(device), imu_data.to(device), labels.to(device)
            
            # Forward pass
            outputs = model(emg_data, imu_data)
            loss = criterion(outputs, labels)
            
            # Update running loss
            running_loss += loss.item()
            
            # Compute accuracy
            _, predicted = outputs.max(1)
            total += labels.size(0)
            correct += predicted.eq(labels).sum().item()

    # Compute accuracy over the whole dataset
    accuracy = 100. * correct / total
    return running_loss / len(dataloader), accuracy

# %%
def train_model(model, train_loader, test_loader, criterion, optimizer, num_epochs, device):   
    model.to(device)
    for epoch in range(num_epochs):
        start_time = time.time()

        # Train the model for one epoch
        train_loss, train_acc = train(model, optimizer, train_loader, criterion, device)

        end_time = time.time()
        epoch_time = end_time - start_time

        print(f"Epoch {epoch+1}/{num_epochs}")
        print(f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.2f}%")
        print(f"Epoch Time: {epoch_time:.2f} seconds")
        test_loss, test_acc = evaluate(model, test_loader, criterion, device)
        print(f"Test Loss: {test_loss:.4f}, Test Acc: {test_acc:.2f}%")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize EMG_IMU_CNN model and move it to the device
emgimu_model = EMG_IMU_CNN().to(device)

# Number of epochs
num_epochs = 100

# Loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(emgimu_model.parameters(), lr=0.0001, weight_decay=1e-3)

# Train the EMG-IMU model
train_model(emgimu_model, train_loader, test_loader, criterion, optimizer, num_epochs, device)
# Out:
# Epoch 1/100
# Train Loss: 2.3173, Train Acc: 10.54%
# Epoch Time: 0.54 seconds
# Test Loss: 2.3408, Test Acc: 10.62%
# Epoch 2/100
# Train Loss: 2.2884, Train Acc: 12.21%
# Epoch Time: 0.55 seconds
# Test Loss: 2.3615, Test Acc: 11.50%
# Epoch 3/100
# Train Loss: 2.2789, Train Acc: 13.46%
# Epoch Time: 0.51 seconds
# Test Loss: 2.3823, Test Acc: 11.50%
# Epoch 4/100
# Train Loss: 2.2603, Train Acc: 15.46%
# Epoch Time: 0.52 seconds
# Test Loss: 2.3929, Test Acc: 11.62%
# Epoch 5/100
# Train Loss: 2.2426, Train Acc: 15.33%
# Epoch Time: 0.52 seconds
# Test Loss: 2.4574, Test Acc: 12.25%
# Epoch 6/100
# Train Loss: 2.2055, Train Acc: 18.79%
# Epoch Time: 0.50 seconds
# Test Loss: 2.5099, Test Acc: 10.88%
# Epoch 7/100
# Train Loss: 2.1665, Train Acc: 21.75%
# Epoch Time: 0.52 seconds
# Test Loss: 2.7117, Test Acc: 10.38%
# Epoch 8/100
# Train Loss: 2.1090, Train Acc: 24.21%
# Epoch Time: 0.52 seconds
# Test Loss: 3.1601, Test Acc: 11.50%
# Epoch 9/100
# Train Loss: 2.0494, Train Acc: 27.58%
# Epoch Time: 0.52 seconds
# Test Loss: 3.3304, Test Acc: 11.25%
# Epoch 10/100
# Train Loss: 1.9627, Train Acc: 32.33%
# Epoch Time: 0.52 seconds
# Test Loss: 3.6789, Test Acc: 12.25%
# Epoch 11/100
# Train Loss: 1.8805, Train Acc: 35.17%
# Epoch Time: 0.52 seconds
# Test Loss: 3.9250, Test Acc: 12.88%
# Epoch 12/100
# Train Loss: 1.7952, Train Acc: 37.58%
# Epoch Time: 0.52 seconds
# Test Loss: 4.5036, Test Acc: 14.12%
# Epoch 13/100
# Train Loss: 1.6904, Train Acc: 41.08%
# Epoch Time: 0.52 seconds
# Test Loss: 5.1062, Test Acc: 14.25%
# Epoch 14/100
# Train Loss: 1.5840, Train Acc: 44.46%
# Epoch Time: 0.52 seconds
# Test Loss: 4.8526, Test Acc: 14.38%
# Epoch 15/100
# Train Loss: 1.4955, Train Acc: 48.50%
# Epoch Time: 0.52 seconds
# Test Loss: 6.1300, Test Acc: 14.38%
# Epoch 16/100
# Train Loss: 1.3892, Train Acc: 53.25%
# Epoch Time: 0.54 seconds
# Test Loss: 6.2731, Test Acc: 14.38%
# Epoch 17/100
# Train Loss: 1.3088, Train Acc: 56.25%
# Epoch Time: 0.52 seconds
# Test Loss: 6.4079, Test Acc: 15.75%
# Epoch 18/100
# Train Loss: 1.2159, Train Acc: 58.88%
# Epoch Time: 0.52 seconds
# Test Loss: 6.1735, Test Acc: 17.62%
# Epoch 19/100
# Train Loss: 1.1464, Train Acc: 61.25%
# Epoch Time: 0.50 seconds
# Test Loss: 6.7282, Test Acc: 18.50%
# Epoch 20/100
# Train Loss: 1.0716, Train Acc: 63.79%
# Epoch Time: 0.52 seconds
# Test Loss: 6.6637, Test Acc: 19.25%
# Epoch 21/100
# Train Loss: 1.0144, Train Acc: 66.00%
# Epoch Time: 0.52 seconds
# Test Loss: 6.8916, Test Acc: 19.00%
# Epoch 22/100
# Train Loss: 0.9236, Train Acc: 69.42%
# Epoch Time: 0.53 seconds
# Test Loss: 7.3759, Test Acc: 18.75%
# Epoch 23/100
# Train Loss: 0.8766, Train Acc: 69.58%
# Epoch Time: 0.53 seconds
# Test Loss: 7.8556, Test Acc: 18.88%
# Epoch 24/100
# Train Loss: 0.8255, Train Acc: 72.46%
# Epoch Time: 0.52 seconds
# Test Loss: 8.1862, Test Acc: 20.00%
# Epoch 25/100
# Train Loss: 0.7615, Train Acc: 74.08%
# Epoch Time: 0.52 seconds
# Test Loss: 8.5054, Test Acc: 19.25%
# Epoch 26/100
# Train Loss: 0.7539, Train Acc: 74.42%
# Epoch Time: 0.52 seconds
# Test Loss: 8.5788, Test Acc: 19.25%
# Epoch 27/100
# Train Loss: 0.6946, Train Acc: 76.33%
# Epoch Time: 0.52 seconds
# Test Loss: 9.6254, Test Acc: 19.38%
# Epoch 28/100
# Train Loss: 0.6432, Train Acc: 78.17%
# Epoch Time: 0.59 seconds
# Test Loss: 8.9973, Test Acc: 18.75%
# Epoch 29/100
# Train Loss: 0.6129, Train Acc: 79.00%
# Epoch Time: 0.52 seconds
# Test Loss: 9.2259, Test Acc: 19.62%
# Epoch 30/100
# Train Loss: 0.5821, Train Acc: 80.83%
# Epoch Time: 0.56 seconds
# Test Loss: 9.0809, Test Acc: 19.25%
# Epoch 31/100
# Train Loss: 0.5535, Train Acc: 82.54%
# Epoch Time: 0.52 seconds
# Test Loss: 9.6729, Test Acc: 20.00%
# Epoch 32/100
# Train Loss: 0.5275, Train Acc: 82.54%
# Epoch Time: 0.53 seconds
# Test Loss: 9.8412, Test Acc: 19.38%
# Epoch 33/100
# Train Loss: 0.5039, Train Acc: 83.71%
# Epoch Time: 0.52 seconds
# Test Loss: 10.4528, Test Acc: 18.88%
# Epoch 34/100
# Train Loss: 0.4846, Train Acc: 84.17%
# Epoch Time: 0.52 seconds
# Test Loss: 10.1976, Test Acc: 20.25%
# Epoch 35/100
# Train Loss: 0.4452, Train Acc: 85.04%
# Epoch Time: 0.52 seconds
# Test Loss: 10.4346, Test Acc: 19.88%
# Epoch 36/100
# Train Loss: 0.4305, Train Acc: 86.38%
# Epoch Time: 0.52 seconds
# Test Loss: 10.0883, Test Acc: 20.25%
# Epoch 37/100
# Train Loss: 0.4455, Train Acc: 85.62%
# Epoch Time: 0.52 seconds
# Test Loss: 9.6830, Test Acc: 20.38%
# Epoch 38/100
# Train Loss: 0.3979, Train Acc: 87.25%
# Epoch Time: 0.52 seconds
# Test Loss: 10.0844, Test Acc: 20.12%
# Epoch 39/100
# Train Loss: 0.3802, Train Acc: 88.08%
# Epoch Time: 0.52 seconds
# Test Loss: 10.1970, Test Acc: 20.75%
# Epoch 40/100
# Train Loss: 0.3510, Train Acc: 88.83%
# Epoch Time: 0.52 seconds
# Test Loss: 10.1509, Test Acc: 20.25%
# Epoch 41/100
# Train Loss: 0.3430, Train Acc: 89.54%
# Epoch Time: 0.52 seconds
# Test Loss: 10.3303, Test Acc: 20.25%
# Epoch 42/100
# Train Loss: 0.3425, Train Acc: 89.00%
# Epoch Time: 0.51 seconds
# Test Loss: 10.1373, Test Acc: 20.88%
# Epoch 43/100
# Train Loss: 0.3263, Train Acc: 90.21%
# Epoch Time: 0.52 seconds
# Test Loss: 11.4136, Test Acc: 19.62%
# Epoch 44/100
# Train Loss: 0.3120, Train Acc: 90.67%
# Epoch Time: 0.52 seconds
# Test Loss: 11.0070, Test Acc: 21.00%
# Epoch 45/100
# Train Loss: 0.2837, Train Acc: 91.46%
# Epoch Time: 0.51 seconds
# Test Loss: 10.6540, Test Acc: 21.38%
# Epoch 46/100
# Train Loss: 0.2610, Train Acc: 91.96%
# Epoch Time: 0.52 seconds
# Test Loss: 10.7458, Test Acc: 21.62%
# Epoch 47/100
# Train Loss: 0.2781, Train Acc: 91.92%
# Epoch Time: 0.52 seconds
# Test Loss: 11.2743, Test Acc: 20.75%
# Epoch 48/100
# Train Loss: 0.2590, Train Acc: 92.12%
# Epoch Time: 0.52 seconds
# Test Loss: 11.3561, Test Acc: 22.00%
# Epoch 49/100
# Train Loss: 0.2552, Train Acc: 92.04%
# Epoch Time: 0.52 seconds
# Test Loss: 11.8533, Test Acc: 22.75%
# Epoch 50/100
# Train Loss: 0.2446, Train Acc: 92.46%
# Epoch Time: 0.53 seconds
# Test Loss: 10.9664, Test Acc: 22.50%
# Epoch 51/100
# Train Loss: 0.2455, Train Acc: 92.83%
# Epoch Time: 0.57 seconds
# Test Loss: 12.5660, Test Acc: 21.62%
# Epoch 52/100
# Train Loss: 0.2190, Train Acc: 93.79%
# Epoch Time: 0.54 seconds
# Test Loss: 11.9669, Test Acc: 22.50%
# Epoch 53/100
# Train Loss: 0.2098, Train Acc: 93.67%
# Epoch Time: 0.62 seconds
# Test Loss: 11.0106, Test Acc: 22.62%
# Epoch 54/100
# Train Loss: 0.2270, Train Acc: 93.33%
# Epoch Time: 0.59 seconds
# Test Loss: 12.1942, Test Acc: 21.62%
# Epoch 55/100
# Train Loss: 0.2062, Train Acc: 93.17%
# Epoch Time: 0.64 seconds
# Test Loss: 12.8020, Test Acc: 21.62%
# Epoch 56/100
# Train Loss: 0.1893, Train Acc: 94.96%
# Epoch Time: 0.55 seconds
# Test Loss: 12.3808, Test Acc: 20.88%
# Epoch 57/100
# Train Loss: 0.1888, Train Acc: 94.88%
# Epoch Time: 0.54 seconds
# Test Loss: 11.7280, Test Acc: 21.50%
# Epoch 58/100
# Train Loss: 0.1842, Train Acc: 94.58%
# Epoch Time: 0.56 seconds
# Test Loss: 12.4678, Test Acc: 20.88%
# Epoch 59/100
# Train Loss: 0.1697, Train Acc: 95.29%
# Epoch Time: 0.58 seconds
# Test Loss: 12.6820, Test Acc: 20.38%
# Epoch 60/100
# Train Loss: 0.1635, Train Acc: 95.38%
# Epoch Time: 0.69 seconds
# Test Loss: 13.6174, Test Acc: 20.88%
# Epoch 61/100
# Train Loss: 0.1780, Train Acc: 95.25%
# Epoch Time: 0.72 seconds
# Test Loss: 13.4193, Test Acc: 21.88%
# Epoch 62/100
# Train Loss: 0.1568, Train Acc: 95.79%
# Epoch Time: 0.64 seconds
# Test Loss: 12.7678, Test Acc: 20.00%
# Epoch 63/100
# Train Loss: 0.1635, Train Acc: 95.08%
# Epoch Time: 0.74 seconds
# Test Loss: 12.4432, Test Acc: 22.00%
# Epoch 64/100
# Train Loss: 0.1434, Train Acc: 95.96%
# Epoch Time: 0.65 seconds
# Test Loss: 13.0667, Test Acc: 20.62%
# Epoch 65/100
# Train Loss: 0.1545, Train Acc: 95.33%
# Epoch Time: 0.61 seconds
# Test Loss: 12.8112, Test Acc: 19.50%
# Epoch 66/100
# Train Loss: 0.1297, Train Acc: 96.54%
# Epoch Time: 0.57 seconds
# Test Loss: 13.1530, Test Acc: 20.88%
# Epoch 67/100
# Train Loss: 0.1308, Train Acc: 96.25%
# Epoch Time: 0.54 seconds
# Test Loss: 13.0339, Test Acc: 20.50%
# Epoch 68/100
# Train Loss: 0.1290, Train Acc: 96.42%
# Epoch Time: 0.53 seconds
# Test Loss: 13.3157, Test Acc: 21.38%
# Epoch 69/100
# Train Loss: 0.1380, Train Acc: 96.46%
# Epoch Time: 0.61 seconds
# Test Loss: 13.4270, Test Acc: 20.88%
# Epoch 70/100
# Train Loss: 0.1317, Train Acc: 96.29%
# Epoch Time: 0.57 seconds
# Test Loss: 14.6014, Test Acc: 21.25%
# Epoch 71/100
# Train Loss: 0.1243, Train Acc: 96.62%
# Epoch Time: 0.62 seconds
# Test Loss: 13.7926, Test Acc: 20.75%
# Epoch 72/100
# Train Loss: 0.1164, Train Acc: 96.92%
# Epoch Time: 0.56 seconds
# Test Loss: 13.9376, Test Acc: 21.00%
# Epoch 73/100
# Train Loss: 0.1098, Train Acc: 96.88%
# Epoch Time: 0.53 seconds
# Test Loss: 14.2131, Test Acc: 20.12%
# Epoch 74/100
# Train Loss: 0.1110, Train Acc: 97.25%
# Epoch Time: 0.55 seconds
# Test Loss: 13.9215, Test Acc: 21.12%
# Epoch 75/100
# Train Loss: 0.1109, Train Acc: 97.25%
# Epoch Time: 0.59 seconds
# Test Loss: 14.5822, Test Acc: 21.12%
# Epoch 76/100
# Train Loss: 0.1138, Train Acc: 96.62%
# Epoch Time: 0.59 seconds
# Test Loss: 14.9734, Test Acc: 19.88%
# Epoch 77/100
# Train Loss: 0.1115, Train Acc: 97.12%
# Epoch Time: 0.57 seconds
# Test Loss: 15.0673, Test Acc: 20.50%
# Epoch 78/100
# Train Loss: 0.1141, Train Acc: 96.71%
# Epoch Time: 0.52 seconds
# Test Loss: 14.8384, Test Acc: 21.12%
# Epoch 79/100
# Train Loss: 0.1020, Train Acc: 97.50%
# Epoch Time: 0.55 seconds
# Test Loss: 15.0410, Test Acc: 21.00%
# Epoch 80/100
# Train Loss: 0.1031, Train Acc: 97.33%
# Epoch Time: 0.57 seconds
# Test Loss: 14.6594, Test Acc: 21.38%
# Epoch 81/100
# Train Loss: 0.0980, Train Acc: 97.25%
# Epoch Time: 0.59 seconds
# Test Loss: 14.7929, Test Acc: 20.12%
# Epoch 82/100
# Train Loss: 0.1046, Train Acc: 96.83%
# Epoch Time: 0.54 seconds
# Test Loss: 13.2537, Test Acc: 20.75%
# Epoch 83/100
# Train Loss: 0.0876, Train Acc: 97.62%
# Epoch Time: 0.55 seconds
# Test Loss: 13.4996, Test Acc: 20.25%
# Epoch 84/100
# Train Loss: 0.0985, Train Acc: 97.00%
# Epoch Time: 0.58 seconds
# Test Loss: 13.3444, Test Acc: 20.88%
# Epoch 85/100
# Train Loss: 0.1026, Train Acc: 96.96%
# Epoch Time: 0.53 seconds
# Test Loss: 14.7117, Test Acc: 20.62%
# Epoch 86/100
# Train Loss: 0.0998, Train Acc: 97.12%
# Epoch Time: 0.56 seconds
# Test Loss: 14.8593, Test Acc: 21.50%
# Epoch 87/100
# Train Loss: 0.0898, Train Acc: 97.79%
# Epoch Time: 0.56 seconds
# Test Loss: 14.0602, Test Acc: 20.75%
# Epoch 88/100
# Train Loss: 0.0933, Train Acc: 97.29%
# Epoch Time: 0.57 seconds
# Test Loss: 13.6225, Test Acc: 21.25%
# Epoch 89/100
# Train Loss: 0.0794, Train Acc: 97.54%
# Epoch Time: 0.53 seconds
# Test Loss: 14.4919, Test Acc: 20.75%
# Epoch 90/100
# Train Loss: 0.0774, Train Acc: 97.96%
# Epoch Time: 0.52 seconds
# Test Loss: 15.4035, Test Acc: 22.00%
# Epoch 91/100
# Train Loss: 0.0842, Train Acc: 97.50%
# Epoch Time: 0.57 seconds
# Test Loss: 16.0325, Test Acc: 21.25%
# Epoch 92/100
# Train Loss: 0.0729, Train Acc: 98.25%
# Epoch Time: 0.52 seconds
# Test Loss: 15.5334, Test Acc: 21.62%
# Epoch 93/100
# Train Loss: 0.0845, Train Acc: 97.54%
# Epoch Time: 0.52 seconds
# Test Loss: 15.1968, Test Acc: 21.00%
# Epoch 94/100
# Train Loss: 0.0855, Train Acc: 97.54%
# Epoch Time: 0.56 seconds
# Test Loss: 14.0174, Test Acc: 21.62%
# Epoch 95/100
# Train Loss: 0.0745, Train Acc: 97.96%
# Epoch Time: 0.53 seconds
# Test Loss: 14.9883, Test Acc: 21.38%
# Epoch 96/100
# Train Loss: 0.0799, Train Acc: 97.67%
# Epoch Time: 0.52 seconds
# Test Loss: 15.4580, Test Acc: 19.88%
# Epoch 97/100
# Train Loss: 0.0792, Train Acc: 97.46%
# Epoch Time: 0.52 seconds
# Test Loss: 14.2143, Test Acc: 20.88%
# Epoch 98/100
# Train Loss: 0.0751, Train Acc: 98.00%
# Epoch Time: 0.52 seconds
# Test Loss: 14.3113, Test Acc: 21.25%
# Epoch 99/100
# Train Loss: 0.0722, Train Acc: 97.83%
# Epoch Time: 0.52 seconds
# Test Loss: 14.9842, Test Acc: 20.75%
# Epoch 100/100
# Train Loss: 0.0566, Train Acc: 98.50%
# Epoch Time: 0.52 seconds
# Test Loss: 14.7167, Test Acc: 21.12%
